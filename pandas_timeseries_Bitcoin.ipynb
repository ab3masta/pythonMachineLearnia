# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
bitcoin = pd.read_csv('data\\BTC-EUR.csv',index_col='Date' , parse_dates=True)
bitcoin.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-06  6709.230957  6824.454590  6684.455566  6824.454590  6824.454590
# 2019-12-07  6824.697754  6863.297363  6805.207031  6832.811523  6832.811523
# 2019-12-08  6828.381348  6903.226563  6759.896484  6839.696289  6839.696289
# 2019-12-09  6837.390137  6885.307617  6657.451172  6689.006836  6689.006836
# 2019-12-10  6685.604004  6692.711914  6532.265137  6561.181152  6561.181152
#
#                   Volume
# Date
# 2019-12-06  1.637116e+10
# 2019-12-07  1.397402e+10
# 2019-12-08  1.393367e+10
# 2019-12-09  1.615291e+10
# 2019-12-10  1.645139e+10

# %%
bitcoin['Close'].plot(figsize=(12,6))
plt.show()

# %%
# Observer l'evolution seulement en 2019
bitcoin['2019-12']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
